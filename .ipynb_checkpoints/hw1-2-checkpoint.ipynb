# %% [markdown]
# # PCA examples

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import time

# %%
rng = np.random.RandomState(int(time.time()))
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal');

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
def draw_vector(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=2,
                    shrinkA=0,
                    shrinkB=0,
                    color='black')
    ax.annotate('', v1, v0, arrowprops=arrowprops)

# plot data
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v)
plt.axis('equal');

# %%
pca = PCA(n_components=2)
pca.fit(X)
X_pca = pca.transform(X)
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)
print(X_pca)
# Out:
# original shape:    (200, 2)
# transformed shape: (200, 2)
# [[-7.69275894e-01  1.07483423e-01]
#  [ 2.26703652e+00 -3.20169746e-02]
#  [ 1.03339203e+00  3.21178877e-02]
#  [-1.27648656e+00 -4.13434661e-02]
#  [ 1.11792264e+00 -1.15711003e-01]
#  [-3.75637895e-01 -5.43833779e-02]
#  [ 6.62954414e-01  2.50765892e-01]
#  [-2.50092796e+00  3.32367454e-01]
#  [ 2.05550045e+00  1.00948838e-01]
#  [-9.30082728e-01  3.05208889e-02]
#  [-1.85401567e-01  1.02393438e-01]
#  [-6.68867825e-02  2.30631922e-01]
#  [ 3.37465992e+00  1.56143385e-01]
#  [-9.20482398e-01  1.27558123e-01]
#  [-6.23128912e-01  2.28502209e-01]
#  [-1.48578623e+00  7.29141038e-02]
#  [ 1.96355306e+00 -4.97604696e-03]
#  [-1.71911297e+00  3.99061385e-02]
#  [-1.59825110e+00 -2.68865719e-01]
#  [-9.64645538e-02 -4.48490631e-01]
#  [-7.37476994e-01  4.62576767e-02]
#  [ 1.55298961e+00 -6.18990220e-02]
#  [ 2.62318703e-01  8.22079563e-02]
#  [ 1.44899078e+00  6.69042003e-02]
#  [-2.09629563e+00 -1.01649366e-01]
#  [-2.39055883e+00  8.91453854e-02]
#  [-9.32059661e-03  2.36804591e-02]
#  [ 2.33335119e+00  1.30341069e-01]
#  [ 1.67531846e-01 -1.71428873e-01]
#  [-1.51437912e+00 -1.08213218e-02]
#  [ 1.06928938e-01 -2.11195773e-01]
#  [ 1.25695944e+00 -1.86441607e-01]
#  [-1.35013848e+00 -3.92798780e-02]
#  [ 1.32014574e+00 -1.38807475e-01]
#  [ 5.73583304e-01 -2.48499775e-01]
#  [-8.74637480e-01 -2.49711368e-02]
#  [-1.09819309e+00 -3.04311278e-01]
#  [-5.74909259e-01  4.82137842e-02]
#  [ 6.61084129e-01  2.74289720e-03]
#  [-1.10174224e+00  1.35442034e-01]
#  [ 4.07996253e-01  1.01095860e-01]
#  [ 1.30761693e+00 -1.85259527e-01]
#  [-6.24923101e-01 -3.10847111e-02]
#  [-9.70559167e-01 -1.03120122e-01]
#  [ 3.66542221e-01  2.21615620e-01]
#  [ 9.94639904e-01  4.12887637e-01]
#  [ 3.56775544e-01 -6.39654323e-02]
#  [ 8.36478632e-01  7.20801289e-02]
#  [-6.34727614e-01 -2.59486285e-01]
#  [ 8.22002208e-01  2.23366350e-01]
#  [ 2.29433413e-01  1.42279862e-01]
#  [ 1.87418409e+00  8.33444400e-02]
#  [-3.00709307e-01 -2.36309905e-01]
#  [-2.98065105e-01 -2.13991754e-01]
#  [ 2.40924692e-01 -4.47761902e-02]
#  [-1.11343166e+00  5.46784060e-02]
#  [ 1.48745838e+00 -6.72691682e-02]
#  [-3.63525029e-01  8.38006984e-02]
#  [-4.94116647e-01  2.02388057e-01]
#  [-4.18154820e-01 -5.95484345e-03]
#  [ 1.01514087e+00  4.22560337e-02]
#  [ 1.55207397e+00 -1.46526653e-01]
#  [-1.09432891e+00  1.06281948e-01]
#  [-2.21108358e-01  1.93402985e-01]
#  [-2.93785304e-01  1.15413173e-01]
#  [-3.62372055e-02  3.64956579e-01]
#  [ 2.10651570e-01 -1.60474811e-01]
#  [-1.66361283e+00 -2.36751404e-02]
#  [ 2.96977318e+00  3.23598101e-01]
#  [-2.28082324e+00  6.60395069e-02]
#  [-8.96326610e-01 -1.20544349e-01]
#  [-8.61936631e-01 -3.34068220e-02]
#  [ 1.19579869e+00 -9.90501282e-02]
#  [-1.41939388e+00  9.14122558e-02]
#  [-7.71150783e-01 -2.21441596e-01]
#  [-1.87400835e-01 -3.12582591e-01]
#  [-7.49913013e-01  3.82487810e-02]
#  [-1.01256575e+00  1.25291551e-01]
#  [ 1.09253033e+00 -2.79748415e-01]
#  [-5.06081540e-01 -1.33480372e-01]
#  [-1.80885758e+00 -2.85902223e-01]
#  [-5.28073771e-01 -1.88451501e-01]
#  [-1.12063808e+00 -1.39307479e-01]
#  [ 1.15955323e+00 -2.27302710e-01]
#  [-1.52681727e+00  1.58191738e-03]
#  [-3.42877036e-02  3.98973290e-01]
#  [-1.73561953e+00  2.38855692e-01]
#  [ 1.42209669e+00  3.20965034e-01]
#  [ 5.96399387e-01  2.22762423e-01]
#  [-6.97157796e-02 -2.42530625e-02]
#  [ 1.34356750e-01 -1.63283199e-02]
#  [ 3.64003159e-01 -8.20755912e-02]
#  [ 8.39214939e-02 -4.19002398e-02]
#  [-8.95117213e-01 -3.75052235e-01]
#  [-1.35197899e+00  1.15948007e-01]
#  [-9.09588081e-01 -2.46432404e-01]
#  [-1.09839027e+00 -2.50492164e-02]
#  [ 5.91666877e-01 -1.62991958e-01]
#  [-1.85516263e+00 -6.81517004e-02]
#  [ 6.57217351e-02  4.09205030e-02]
#  [ 3.10759830e+00  2.29658253e-02]
#  [ 3.19813133e-01  1.27447397e-01]
#  [ 3.44270170e-02  6.06039995e-02]
#  [-1.20181005e+00 -3.19858797e-01]
#  [ 2.06034389e-01  5.93223686e-02]
#  [-1.44685165e+00  3.19579063e-01]
#  [ 2.83631974e-01 -3.78601971e-02]
#  [ 1.77700988e+00 -2.35440720e-01]
#  [ 1.34567626e+00  4.32751438e-01]
#  [-1.07963368e-01 -1.42248945e-01]
#  [-9.56098521e-01  3.25872923e-01]
#  [ 3.38735424e-01  1.16789806e-02]
#  [ 1.96054932e+00 -3.26318381e-01]
#  [ 2.48621563e-01  2.03403202e-02]
#  [-2.46951570e+00 -2.95931727e-01]
#  [ 1.81097105e+00  1.24516759e-02]
#  [ 2.19509619e-01  2.33056058e-01]
#  [-6.33592883e-01 -3.57100196e-02]
#  [ 8.16232671e-01 -5.56514368e-02]
#  [ 6.04021405e-01 -2.71750248e-01]
#  [-1.40049753e+00  1.68784018e-01]
#  [-4.67742381e-01  3.95016123e-02]
#  [ 3.97349284e-01 -2.34711352e-01]
#  [-8.29494069e-02  3.28976832e-01]
#  [-7.49935854e-01  2.76693840e-01]
#  [-1.45299336e+00  1.64783497e-01]
#  [-3.85226413e-02 -8.24008819e-02]
#  [-8.20219331e-01 -2.72636501e-01]
#  [ 5.58768404e-01  4.94955135e-02]
#  [ 5.17288470e-01 -3.07940152e-01]
#  [ 4.67823983e-01  1.08335514e-01]
#  [ 2.70236804e+00 -1.65971149e-02]
#  [-1.10265889e-01  1.02641137e-01]
#  [-5.39147173e-01 -5.89667176e-02]
#  [ 2.34213878e+00 -4.02848564e-01]
#  [ 9.05785622e-01  1.65584596e-01]
#  [ 5.54344596e-01  9.83439189e-02]
#  [-6.38945993e-01  1.93464083e-01]
#  [ 2.46724907e-01 -3.72331499e-01]
#  [-6.23746329e-01 -1.36006923e-01]
#  [ 1.35606796e-01 -7.18210575e-02]
#  [ 3.87323157e-01  3.26939435e-01]
#  [ 1.56318952e+00 -2.35595587e-01]
#  [ 4.80412809e-01  8.02394986e-02]
#  [ 1.54749129e-01  1.74908046e-02]
#  [ 1.98512457e+00 -4.05497245e-01]
#  [ 5.53390586e-01  1.01427481e-01]
#  [ 4.69682669e-01  2.84331900e-01]
#  [ 1.64917365e-02  4.19097934e-01]
#  [ 3.40422231e-01  1.19038491e-01]
#  [ 2.61851683e-02 -3.35496240e-01]
#  [ 3.12865325e-01 -1.12208288e-01]
#  [ 7.55331300e-01  2.08891846e-01]
#  [-5.95106113e-02  1.15043562e-01]
#  [-5.81210323e-01 -2.09798483e-01]
#  [-3.14522980e-01  9.20273638e-02]
#  [-1.69793009e+00 -2.51231729e-01]
#  [ 1.94521545e-01  3.33412258e-01]
#  [-4.58568412e-01  1.70157783e-02]
#  [-1.09139083e+00  1.36874971e-01]
#  [ 1.11053132e+00 -1.84167173e-01]
#  [-1.79341729e-01  2.55516451e-01]
#  [ 9.39063630e-01 -5.67848971e-02]
#  [-1.17770313e+00 -2.67071390e-01]
#  [-1.93050036e-01  4.77519190e-01]
#  [ 1.59959059e+00 -2.48618440e-01]
#  [-7.08092819e-01  1.32071343e-01]
#  [ 5.45283028e-01 -1.47212523e-01]
#  [ 3.91212811e-01  1.03050344e-01]
#  [ 9.88582126e-01 -1.16198410e-01]
#  [-2.39487206e+00  7.83489855e-02]
#  [-1.14825214e+00 -1.23024879e-01]
#  [-9.63405270e-01 -9.32855101e-02]
#  [ 1.48516293e+00  8.59179317e-02]
#  [-6.83988488e-02 -1.72294547e-01]
#  [-5.83122648e-01  1.65522493e-01]
#  [ 1.75812513e+00  1.19235933e-01]
#  [ 1.00727862e+00  1.96070936e-01]
#  [-1.70554781e-01  6.07371459e-02]
#  [ 1.07101458e+00 -2.72828078e-01]
#  [-1.03135223e-01  2.19713151e-02]
#  [-4.85565954e-01 -1.85864389e-01]
#  [-3.79739626e-01  2.04288600e-01]
#  [ 9.13457856e-01 -1.51855406e-01]
#  [ 5.95573781e-01  1.97106044e-01]
#  [-1.09396787e+00  9.66576070e-02]
#  [-4.32595940e-01 -3.42572779e-02]
#  [ 2.48840677e+00 -8.92558938e-02]
#  [-6.58666369e-01  1.25235250e-01]
#  [ 1.39349209e+00 -4.94517096e-02]
#  [-8.02987894e-01 -1.70249938e-01]
#  [ 4.44180464e-01  5.98163989e-02]
#  [-1.01033957e+00  3.85597158e-02]
#  [ 1.85215805e-01  5.83773318e-02]
#  [-8.57680654e-01 -4.48666773e-01]
#  [-2.60903409e+00 -6.25453713e-02]
#  [-8.45889681e-01  1.93720610e-01]
#  [-1.52807049e-01 -1.36492233e-01]
#  [ 1.62947732e+00  2.84207256e-01]
#  [-1.81717624e+00 -4.26469940e-02]]

# %%
X_new = pca.inverse_transform(X_pca)
plt.scatter(X[:, 0], X[:, 1], alpha=0.3)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.7)
plt.axis('equal');

# %%
import cv2
import os
import numpy as np
import copy
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def normalize(image):
    
    max_value = np.max(image)
    min_value = np.min(image)
    return 255 * ((image - min_value) / (max_value - min_value))

image_folder = "D:/User/Desktop/DLCV/hw1/p2_data"
num_features = 56 * 46
data = np.zeros((10*40, num_features), dtype=np.uint8)
training_data = np.zeros((9*40, num_features), dtype=np.uint8)
testing_data = np.zeros((1*40, num_features), dtype=np.uint8)

# Get training and testing data
filenames = sorted(os.listdir(image_folder), key=lambda filename:(int(filename.split("_")[0]), int(filename.split("_")[1].split(".")[0])))
for index, filename in enumerate(filenames):
    data[index, :] = cv2.imread(os.path.join("hw1/p2_data", filename), cv2.IMREAD_GRAYSCALE).flatten()
    i = int(filename.split("_")[0])
    j = int(filename.split("_")[1].split(".")[0])
    
    if j == 10:
        testing_data[i-1, :] =  data[index, :]
    else:
        training_data[(i-1)*9 + (j-1), :] = data[index, :]

# Performing PCA
num_extracted_features = 4
pca = PCA(n_components=4)
pca.fit(training_set)
eigenfaces = np.zeros((num_extracted_features, 56, 46))
for i in range(num_extracted_features):
    eigenfaces[i, :, :] = pca.components_[i].reshape((56, 46))


# Show result
fig = plt.figure(figsize=(8, 8))
for i in range(1, num_extracted_features + 1):
    fig.add_subplot(1, num_extracted_features, i)
    plt.imshow(normalize(eigenfaces[i-1, :, :]), cmap='gray', vmin=0, vmax=255)
    # plt.imshow(eigenfaces[i-1, :, :], cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
i = 2
j = 1
index = [3, 50, 170, 240, 345]
image = data[(i-1)*10 + (j-1), :][:]
mse = np.zeros(5)

fig = plt.figure(figsize=(8, 8))
for i in range(5):
    pca = PCA(n_components=index[i])
    pca.fit(training_set)
    image_pca = pca.transform([image])

    # Show result
    fig.add_subplot(1, 5, i+1)
    reconstructed = pca.inverse_transform(image_pca)
    mse[i] = np.linalg.norm(reconstructed - image, 2)
    plt.imshow(reconstructed.reshape((56, 46)), cmap='gray', vmin=0, vmax=255)
plt.show()
print(f"MSE : {mse}")
# Out:
# [1386.99508819  783.15335637  368.18143955  187.57212865   23.55754462]

# %%
train = training_set.reshape((3, 120, 56*46))
validation_data = np.zeros((120, 56*46))
training_data = np.zeros((240, 56*46))
for i in range(3):
    index = [0, 1, 2]
    index.remove(i)
    validation_data = train[i, :, :]
    for k in range(len(index)):
        training_data[k*120:(k+1)*120, :] = train[index[k], :, :]

# %%
b = image.flatten().reshape((56, 46))
k = 0
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        if image[i, j] != b[i, j]:
            print("123")
        k += 1

# %%
a = np.array([1, 2, 3, 4, 5, 6])
print(a.reshape((3, 2)))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %% [markdown]
# # K-means

# %%
import numpy as np
import time

def kmeans(k, data):

    # initialize, randomly pick k instances as center
    np.random.seed(int(time.time()))
    
    # get k differnect centers
    while True:
        random_index = np.random.randint(data.shape[0], size=k)
        centers = data[random_index, :]
        if np.unique(centers, axis=0).shape[0] == k:
            break
    
    distance_table = np.zeros((centers.shape[0], data.shape[0]))
    
    # iterate untill stop changing or max iteration
    itermax = 1000
    changed = True
    iter = 0
    while changed and iter < itermax:
        
        # Show for debug
        print(f"iter : {iter}")
        # print(f"centers : \n{centers}")

        for idx, center in enumerate(centers):
            distance = data - center
            distance_table[idx, :] = np.linalg.norm(distance, 2, axis=1)
        

        clusters = np.argmin(distance_table, axis=0)
        
        new_centers = np.zeros((k, centers.shape[1]))
        for idx in range(k):
            instances = data[clusters == idx]
            new_centers[idx, :] = np.mean(instances, axis=0)

        if np.array_equal(centers, new_centers):
            changed = False
        else:
            centers = new_centers
            iter += 1

    return centers

# %%
import copy

def visualize(image, centers):
    new_image = copy.deepcopy(image)
    for row in range(new_image.shape[0]):
        for col in range(new_image.shape[1]):
            
            distances = np.linalg.norm(new_image[row, col, :] - centers, 2, axis=1)
            min_index = np.argmin(distances)
            new_image[row, col, :] = centers[min_index]
            
    return new_image

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("hw1/bird.jpg")
print(image.shape)
# Show for debug
plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (1024, 1024, 3)

# %%
data = np.zeros((image.shape[0] * image.shape[1], 3))
i = 0

for row in image:
    for pixel in row:
        data[i] = pixel
        i += 1
        
np.set_printoptions(precision=4)

# %% [markdown]
# # K = 2

# %%
centers = kmeans(2, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgb_2.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# True

# %% [markdown]
# # K = 4

# %%
centers = kmeans(4, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgb_4.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# True

# %% [markdown]
# # K= 8

# %%
centers = kmeans(8, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgb_8.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# True

# %% [markdown]
# # K = 16

# %%
centers = kmeans(16, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgb_16.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# True

# %% [markdown]
# # K = 32

# %%
centers = kmeans(32, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgb_32.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# iter : 86
# iter : 87
# iter : 88
# iter : 89
# iter : 90
# iter : 91
# iter : 92
# iter : 93
# iter : 94
# iter : 95
# iter : 96
# iter : 97
# iter : 98
# iter : 99
# iter : 100
# iter : 101
# iter : 102
# iter : 103
# iter : 104
# iter : 105
# iter : 106
# iter : 107
# iter : 108
# iter : 109
# iter : 110
# iter : 111
# iter : 112
# iter : 113
# iter : 114
# iter : 115
# iter : 116
# iter : 117
# iter : 118
# iter : 119
# iter : 120
# iter : 121
# iter : 122
# iter : 123
# iter : 124
# iter : 125
# iter : 126
# iter : 127
# iter : 128
# iter : 129
# iter : 130
# iter : 131
# iter : 132
# iter : 133
# iter : 134
# iter : 135
# iter : 136
# iter : 137
# iter : 138
# iter : 139
# iter : 140
# iter : 141
# iter : 142
# iter : 143
# iter : 144
# iter : 145
# iter : 146
# iter : 147
# iter : 148
# iter : 149
# iter : 150
# iter : 151
# iter : 152
# iter : 153
# iter : 154
# iter : 155
# iter : 156
# iter : 157
# iter : 158
# iter : 159
# iter : 160
# iter : 161
# iter : 162
# iter : 163
# iter : 164
# iter : 165
# iter : 166
# iter : 167
# iter : 168
# iter : 169
# iter : 170
# iter : 171
# iter : 172
# iter : 173
# iter : 174
# iter : 175
# iter : 176
# True

# %%
data = np.zeros((image.shape[0] * image.shape[1], 5))
i = 0

for row in range(image.shape[0]):
    for col in range(image.shape[1]):
        data[i] = np.concatenate((image[row, col, :], np.array([row, col])))
        i += 1
print(data)
np.set_printoptions(precision=4)
# Out:
# [[1.000e+02 1.750e+02 1.290e+02 0.000e+00 0.000e+00]
#  [1.000e+02 1.750e+02 1.290e+02 0.000e+00 1.000e+00]
#  [1.000e+02 1.750e+02 1.290e+02 0.000e+00 2.000e+00]
#  ...
#  [1.090e+02 2.070e+02 1.530e+02 1.023e+03 1.021e+03]
#  [1.090e+02 2.070e+02 1.530e+02 1.023e+03 1.022e+03]
#  [1.090e+02 2.070e+02 1.530e+02 1.023e+03 1.023e+03]]

# %% [markdown]
# # K = 2

# %%
import copy

def visualize(image, centers):
    new_image = copy.deepcopy(image)
    for row in range(new_image.shape[0]):
        for col in range(new_image.shape[1]):
            coordinate = np.concatenate((new_image[row, col, :], [row, col]))
            distances = np.linalg.norm(coordinate - centers, 2, axis=1)
            min_index = np.argmin(distances)
            new_image[row, col, :] = centers[min_index][:3]
            
    return new_image

# %%
centers = kmeans(2, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_2.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# True

# %% [markdown]
# # K = 4

# %%
centers = kmeans(4, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_4.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# True

# %% [markdown]
# # K = 8

# %%
centers = kmeans(8, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_8.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# iter : 86
# iter : 87
# iter : 88
# iter : 89
# iter : 90
# iter : 91
# iter : 92
# iter : 93
# iter : 94
# iter : 95
# iter : 96
# iter : 97
# iter : 98
# iter : 99
# iter : 100
# iter : 101
# iter : 102
# iter : 103
# iter : 104
# iter : 105
# iter : 106
# iter : 107
# iter : 108
# iter : 109
# iter : 110
# iter : 111
# True

# %% [markdown]
# # K = 16

# %%
centers = kmeans(16, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_16.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# iter : 86
# iter : 87
# iter : 88
# iter : 89
# iter : 90
# iter : 91
# iter : 92
# iter : 93
# iter : 94
# iter : 95
# iter : 96
# iter : 97
# iter : 98
# iter : 99
# iter : 100
# iter : 101
# iter : 102
# iter : 103
# iter : 104
# iter : 105
# iter : 106
# iter : 107
# iter : 108
# iter : 109
# iter : 110
# iter : 111
# iter : 112
# iter : 113
# iter : 114
# iter : 115
# iter : 116
# iter : 117
# iter : 118
# iter : 119
# iter : 120
# iter : 121
# iter : 122
# iter : 123
# iter : 124
# iter : 125
# True

# %% [markdown]
# # K = 32

# %%
centers = kmeans(32, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_32.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# iter : 86
# iter : 87
# iter : 88
# iter : 89
# iter : 90
# iter : 91
# iter : 92
# iter : 93
# iter : 94
# iter : 95
# iter : 96
# iter : 97
# iter : 98
# iter : 99
# iter : 100
# iter : 101
# iter : 102
# iter : 103
# iter : 104
# iter : 105
# iter : 106
# iter : 107
# iter : 108
# iter : 109
# iter : 110
# iter : 111
# iter : 112
# iter : 113
# iter : 114
# iter : 115
# iter : 116
# iter : 117
# iter : 118
# iter : 119
# iter : 120
# iter : 121
# iter : 122
# iter : 123
# iter : 124
# iter : 125
# iter : 126
# iter : 127
# iter : 128
# iter : 129
# iter : 130
# iter : 131
# iter : 132
# iter : 133
# iter : 134
# iter : 135
# iter : 136
# iter : 137
# iter : 138
# iter : 139
# iter : 140
# iter : 141
# iter : 142
# iter : 143
# iter : 144
# iter : 145
# iter : 146
# iter : 147
# iter : 148
# iter : 149
# iter : 150
# iter : 151
# iter : 152
# iter : 153
# iter : 154
# iter : 155
# iter : 156
# iter : 157
# iter : 158
# iter : 159
# iter : 160
# iter : 161
# iter : 162
# iter : 163
# iter : 164
# iter : 165
# iter : 166
# iter : 167
# iter : 168
# iter : 169
# iter : 170
# iter : 171
# iter : 172
# iter : 173
# iter : 174
# iter : 175
# iter : 176
# iter : 177
# iter : 178
# iter : 179
# iter : 180
# iter : 181
# iter : 182
# iter : 183
# iter : 184
# iter : 185
# iter : 186
# iter : 187
# iter : 188
# iter : 189
# iter : 190
# iter : 191
# iter : 192
# iter : 193
# iter : 194
# iter : 195
# iter : 196
# iter : 197
# iter : 198
# iter : 199
# iter : 200
# iter : 201
# iter : 202
# iter : 203
# iter : 204
# iter : 205
# iter : 206
# iter : 207
# iter : 208
# iter : 209
# iter : 210
# iter : 211
# iter : 212
# iter : 213
# iter : 214
# iter : 215
# iter : 216
# iter : 217
# iter : 218
# iter : 219
# iter : 220
# iter : 221
# iter : 222
# iter : 223
# iter : 224
# iter : 225
# iter : 226
# iter : 227
# iter : 228
# iter : 229
# iter : 230
# iter : 231
# iter : 232
# iter : 233
# iter : 234
# iter : 235
# iter : 236
# iter : 237
# iter : 238
# iter : 239
# iter : 240
# iter : 241
# iter : 242
# iter : 243
# iter : 244
# iter : 245
# iter : 246
# iter : 247
# iter : 248
# iter : 249
# iter : 250
# iter : 251
# iter : 252
# iter : 253
# iter : 254
# iter : 255
# iter : 256
# iter : 257
# iter : 258
# iter : 259
# iter : 260
# iter : 261
# iter : 262
# iter : 263
# iter : 264
# iter : 265
# iter : 266
# iter : 267
# iter : 268
# iter : 269
# iter : 270
# iter : 271
# iter : 272
# iter : 273
# iter : 274
# iter : 275
# iter : 276
# iter : 277
# iter : 278
# iter : 279
# iter : 280
# iter : 281
# iter : 282
# iter : 283
# iter : 284
# iter : 285
# iter : 286
# iter : 287
# iter : 288
# iter : 289
# iter : 290
# iter : 291
# iter : 292
# iter : 293
# iter : 294
# iter : 295
# iter : 296
# iter : 297
# iter : 298
# iter : 299
# iter : 300
# iter : 301
# iter : 302
# iter : 303
# iter : 304
# iter : 305
# iter : 306
# iter : 307
# iter : 308
# iter : 309
# iter : 310
# iter : 311
# iter : 312
# iter : 313
# iter : 314
# True

# %%
data = np.zeros((image.shape[0] * image.shape[1], 5))
i = 0

def normalize(image):
    new_image = np.zeros(image.shape)
    for i in range(3):
        new_image[:, :, i] = (image[:, :, i] - np.min(image[:, :, i])) / (np.max(image[:, :, i]) - np.min(image[:, :, i]))
    return new_image
        
new_image = normalize(image)
for row in range(image.shape[0]):
    for col in range(image.shape[1]):
        data[i] = np.concatenate((image[row, col, :], np.array([row/1023.0, col/1023.0])))
        i += 1
print(data)
np.set_printoptions(precision=4)
# Out:
# [[1.0000e+02 1.7500e+02 1.2900e+02 0.0000e+00 0.0000e+00]
#  [1.0000e+02 1.7500e+02 1.2900e+02 0.0000e+00 9.7752e-04]
#  [1.0000e+02 1.7500e+02 1.2900e+02 0.0000e+00 1.9550e-03]
#  ...
#  [1.0900e+02 2.0700e+02 1.5300e+02 1.0000e+00 9.9804e-01]
#  [1.0900e+02 2.0700e+02 1.5300e+02 1.0000e+00 9.9902e-01]
#  [1.0900e+02 2.0700e+02 1.5300e+02 1.0000e+00 1.0000e+00]]

# %% [markdown]
# # K = 2

# %%
centers = kmeans(2, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_normalize_2.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# True

# %% [markdown]
# # K = 4

# %%
centers = kmeans(4, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_normalize_4.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# True

# %% [markdown]
# # K = 8

# %%
centers = kmeans(8, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_normalize_8.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# True

# %% [markdown]
# # K = 16

# %%
centers = kmeans(16, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_normalize_16.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# True

# %% [markdown]
# # K = 32

# %%
centers = kmeans(32, data)
new_image = visualize(image, centers)

plt.axis("off")
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

cv2.imwrite("hw1/results/kmeans_rgbxy_normalize_32.png", new_image)
# Out:
# iter : 0
# iter : 1
# iter : 2
# iter : 3
# iter : 4
# iter : 5
# iter : 6
# iter : 7
# iter : 8
# iter : 9
# iter : 10
# iter : 11
# iter : 12
# iter : 13
# iter : 14
# iter : 15
# iter : 16
# iter : 17
# iter : 18
# iter : 19
# iter : 20
# iter : 21
# iter : 22
# iter : 23
# iter : 24
# iter : 25
# iter : 26
# iter : 27
# iter : 28
# iter : 29
# iter : 30
# iter : 31
# iter : 32
# iter : 33
# iter : 34
# iter : 35
# iter : 36
# iter : 37
# iter : 38
# iter : 39
# iter : 40
# iter : 41
# iter : 42
# iter : 43
# iter : 44
# iter : 45
# iter : 46
# iter : 47
# iter : 48
# iter : 49
# iter : 50
# iter : 51
# iter : 52
# iter : 53
# iter : 54
# iter : 55
# iter : 56
# iter : 57
# iter : 58
# iter : 59
# iter : 60
# iter : 61
# iter : 62
# iter : 63
# iter : 64
# iter : 65
# iter : 66
# iter : 67
# iter : 68
# iter : 69
# iter : 70
# iter : 71
# iter : 72
# iter : 73
# iter : 74
# iter : 75
# iter : 76
# iter : 77
# iter : 78
# iter : 79
# iter : 80
# iter : 81
# iter : 82
# iter : 83
# iter : 84
# iter : 85
# iter : 86
# iter : 87
# iter : 88
# iter : 89
# iter : 90
# iter : 91
# iter : 92
# iter : 93
# iter : 94
# iter : 95
# iter : 96
# iter : 97
# iter : 98
# iter : 99
# iter : 100
# iter : 101
# iter : 102
# iter : 103
# iter : 104
# iter : 105
# iter : 106
# iter : 107
# iter : 108
# iter : 109
# iter : 110
# iter : 111
# iter : 112
# iter : 113
# iter : 114
# iter : 115
# iter : 116
# iter : 117
# iter : 118
# iter : 119
# iter : 120
# iter : 121
# iter : 122
# iter : 123
# iter : 124
# iter : 125
# iter : 126
# iter : 127
# iter : 128
# iter : 129
# iter : 130
# iter : 131
# iter : 132
# iter : 133
# iter : 134
# iter : 135
# iter : 136
# iter : 137
# iter : 138
# iter : 139
# iter : 140
# iter : 141
# iter : 142
# iter : 143
# iter : 144
# iter : 145
# iter : 146
# iter : 147
# iter : 148
# iter : 149
# iter : 150
# iter : 151
# iter : 152
# iter : 153
# iter : 154
# iter : 155
# iter : 156
# iter : 157
# iter : 158
# iter : 159
# iter : 160
# iter : 161
# iter : 162
# iter : 163
# iter : 164
# iter : 165
# iter : 166
# iter : 167
# iter : 168
# iter : 169
# iter : 170
# iter : 171
# iter : 172
# iter : 173
# iter : 174
# iter : 175
# iter : 176
# iter : 177
# iter : 178
# iter : 179
# iter : 180
# iter : 181
# iter : 182
# iter : 183
# iter : 184
# iter : 185
# iter : 186
# True

# %% [markdown]
# # Gussian Filter

# %%
import copy

def filter2D(gray_image, kernel):

    margin_row = kernel.shape[0] // 2
    margin_col = kernel.shape[1] // 2
    filtered = np.zeros((gray_image.shape[0] - 2*margin_row, gray_image.shape[1] - 2*margin_col))

    for row in range(margin_row, gray_image.shape[0] - margin_row):
        for col in range(margin_col, gray_image.shape[1] - margin_col):
            aggregated = np.multiply(gray_image[row-margin_row:row+margin_row+1, col-margin_col:col+margin_col+1], kernel)
            filtered[row-margin_row, col-margin_col] = np.sum(aggregated)
    
    return filtered

# %%
import math

def getGussianKernel(size, sigma):
    gussian_kernel = np.zeros(size)
    margin_row = gussian_kernel.shape[0] // 2
    margin_col = gussian_kernel.shape[1] // 2

    for row in range(-1 * margin_row, margin_row + 1):
        for col in range(-1 * margin_col, margin_col + 1):
            exponents = (-1 * (row**2 + col**2)) / (2 * (sigma**2))
            gussian_kernel[row + margin_row, col + margin_col] =  (1/(2*math.pi*(sigma**2))) *  math.exp(exponents)
    return gussian_kernel

# %%
gray = cv2.imread("hw1/lena.png", cv2.IMREAD_GRAYSCALE)
sigma = 1 / ( 2 * math.log(2) )
gussian_kernel = getGussianKernel((3, 3), sigma)
filtered = filter2D(gray, gussian_kernel)

# Test case
# gray = cv2.imread("hw1/lena.png", cv2.IMREAD_GRAYSCALE)
# avg_kernel = np.ones(25, 25) / 625
# filtered = filter2D(gray, avg_kernel)

plt.axis("off")
plt.imshow(filtered, cmap='gray', vmin=0, vmax=255)
plt.show()
cv2.imwrite("hw1/results/gussianblur.png", filtered)
# Out:
# True

# %% [markdown]
# # Derivatives

# %%
def conv1d(data, kernel):
    
    margin = kernel.shape[0] // 2
    conv = np.zeros(data.shape[0] - 2*margin)
    
    for i in range(margin, data.shape[0] - margin):
        aggregated = np.multiply(data[i-margin:i+margin+1], np.flip(kernel))
        conv[i-margin] = np.sum(aggregated)
    
    return conv

def normalize(gray_image):
    min_value = np.min(gray_image)
    max_value = np.max(gray_image)
    
    new_gray_image = (255 * (gray_image - min_value) / (max_value - min_value)).astype(np.int)
    return new_gray_image

kernel_x = np.array([0.5, 0, -0.5]).T
kernel_y = np.array([0.5, 0, -0.5])
margin_x = kernel_x.shape[0] // 2
margin_y = kernel_y.shape[0] // 2

# Ix = np.zeros((gray.shape[0] - 2*margin_x, gray.shape[1]))
# Iy = np.zeros((gray.shape[0], gray.shape[1] - 2*margin_y)) 

Ix = np.zeros((gray.shape[0], gray.shape[1]))
Iy = np.zeros((gray.shape[0], gray.shape[1])) 

# Get Ix
for row in range(gray.shape[0]):
    Iy[row, :] = conv1d(np.pad(gray[row, :], (1, 1), 'constant', constant_values=0), kernel_x)

# Get Iy
for col in range(gray.shape[1]):
    Ix[:, col] = conv1d(np.pad(gray[:, col], (1, 1), 'constant', constant_values=0), kernel_y)

# %%
plt.axis("off")
plt.imshow(Ix, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
plt.axis("off")
plt.imshow(normalize(abs(Ix)), cmap='gray', vmin=0, vmax=255)
plt.show()

cv2.imwrite(f"hw1/results/normalized_abs_Iy.png", normalize(abs(Ix)))
cv2.imwrite(f"hw1/results/normalized_Iy.png", normalize(Ix))
# Out:
# True

# %%
plt.axis("off")
plt.imshow(normalize(abs(Iy)), cmap='gray', vmin=0, vmax=255)
plt.show()

cv2.imwrite(f"hw1/results/normalized_abs_Ix.png", normalize(abs(Iy)))
cv2.imwrite(f"hw1/results/normalized_Ix.png", normalize(Iy))
# Out:
# True

# %%
def get_gradient_magnitued(gray):
    kernel_x = np.array([0.5, 0, -0.5])
    kernel_y = np.array([0.5, 0, -0.5]).T
    margin_x = kernel_x.shape[0] // 2
    margin_y = kernel_y.shape[0] // 2

    Ix = np.zeros((gray.shape[0], gray.shape[1]))
    Iy = np.zeros((gray.shape[0], gray.shape[1])) 

    # Get Ix
    for row in range(gray.shape[0]):
        Iy[row, :] = conv1d(np.pad(gray[row, :], (1, 1), 'constant', constant_values=0), kernel_x)

    # Get Iy
    for col in range(gray.shape[1]):
        Ix[:, col] = conv1d(np.pad(gray[:, col], (1, 1), 'constant', constant_values=0), kernel_x)
        
    return np.sqrt(np.power(Ix, 2) + np.power(Iy, 2))

# %%
gray_gradient = get_gradient_magnitued(gray)
gussian_gradient = get_gradient_magnitued(filter2D(gray, gussian_kernel))

# %%
plt.axis("off")
plt.imshow(normalize(abs(gray_gradient)), cmap='gray', vmin=0, vmax=255)
plt.show()

cv2.imwrite(f"hw1/results/normalized_gray_gradient.png", normalize(gray_gradient))
# Out:
# True

# %%
plt.axis("off")
plt.imshow(normalize(abs(gussian_gradient)), cmap='gray', vmin=0, vmax=255)
plt.show()

cv2.imwrite(f"hw1/results/normalized_gussian_gradient.png", normalize(gussian_gradient))
# Out:
# True

# %%
np.linalg.norm([[1, 1 ,1], [2, 2, 2]], 2, axis=0)
# Out:
# array([2.23606798, 2.23606798, 2.23606798])

# %%
np.argmin([[1, 1 ,1], [1, 1, 1]], axis=0)
# Out:
# array([0, 0, 0])

# %%
a = np.array([[1, 1 ,1], [2, 2, 2]])
np.power(a, 2)
# Out:
# array([[1, 1, 1],
#        [4, 4, 4]])

# %%
np.unique([[1, 1 ,1], [2, 2, 2]], axis=0)
# Out:
# array([[1, 1, 1],
#        [2, 2, 2]])

# %%
print(f"2-norm : {np.linalg.norm([0.00000000000000000001, 0.00000000000001, 0.0000000000020], 2)}")
# Out:
# 2-norm : 2.000024999843752e-12

# %%
a = np.ones((3, 3))
a = np.pad(a, ((0, 0), (1, 1)), 'constant', constant_values=0)
print(a)
# Out:
# [[0. 1. 1. 1. 0.]
#  [0. 1. 1. 1. 0.]
#  [0. 1. 1. 1. 0.]]

# %%
import numpy as np
import time

def kmeans(k, data):

    # initialize, randomly pick k instances as center
    np.random.seed(int(time.time()))
    
    # get k differnect centers
    while True:
        random_index = np.random.randint(data.shape[0], size=k)
        centers = data[random_index, :]
        if np.unique(centers, axis=0).shape[0] == k:
            break
    
    distance_table = np.zeros((centers.shape[0], data.shape[0]))
    
    # iterate untill stop changing or max iteration
    itermax = 1000
    changed = True
    iter = 0
    while changed and iter < itermax:
        
        # Show for debug
        print(f"iter : {iter}")
        # print(f"centers : \n{centers}")
        
        
        data = np.array([data[:] for _ in range(len(centers))])
        for idx, center in enumerate(centers):
            distance = data - center
            distance_table[idx, :] = np.linalg.norm(distance, 2, axis=1)
        

        clusters = np.argmin(distance_table, axis=0)
        
        new_centers = np.zeros((k, centers.shape[1]))
        for idx in range(k):
            instances = data[clusters == idx]
            new_centers[idx, :] = np.mean(instances, axis=0)

        if np.array_equal(centers, new_centers):
            changed = False
        else:
            centers = new_centers
            iter += 1

    return centers
